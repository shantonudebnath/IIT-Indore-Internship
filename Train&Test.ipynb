# %%
import numpy as np
import pandas as pd
import sklearn
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
import pickle

# %% [markdown]
# # ReadThe Dataset In CSV File Format

# %%
data = pd.read_csv("kc_house_data.csv")

#Print the CSV File

data
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 0      7129300520  20141013T000000  221900.0         3       1.00
# 1      6414100192  20141209T000000  538000.0         3       2.25
# 2      5631500400  20150225T000000  180000.0         2       1.00
# 3      2487200875  20141209T000000  604000.0         4       3.00
# 4      1954400510  20150218T000000  510000.0         3       2.00
# ...           ...              ...       ...       ...        ...
# 21608   263000018  20140521T000000  360000.0         3       2.50
# 21609  6600060120  20150223T000000  400000.0         4       2.50
# 21610  1523300141  20140623T000000  402101.0         2       0.75
# 21611   291310100  20150116T000000  400000.0         3       2.50
# 21612  1523300157  20141015T000000  325000.0         2       0.75
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 0             1180      5650     1.0           0     0  ...      7
# ...

# %% [markdown]
# #  The Dataset in Training & Testing

# %%
# This is Supervised learning

# Get the Input and Output

# The House Price Prediction In needs input are

#Bedrooms, Bathrooms,sqft_living, sqft_lot ,floors, waterfront, sqft_above,sqft_basement,r_built

# The output need only price

#Price

dipt = data[["bedrooms","bathrooms","sqft_living","sqft_lot","floors","waterfront","sqft_above","sqft_basement","yr_built"]]

#Print the input
dipt
# Out:
#        bedrooms  bathrooms  sqft_living  sqft_lot  floors  waterfront  \
# 0             3       1.00         1180      5650     1.0           0
# 1             3       2.25         2570      7242     2.0           0
# 2             2       1.00          770     10000     1.0           0
# 3             4       3.00         1960      5000     1.0           0
# 4             3       2.00         1680      8080     1.0           0
# ...         ...        ...          ...       ...     ...         ...
# 21608         3       2.50         1530      1131     3.0           0
# 21609         4       2.50         2310      5813     2.0           0
# 21610         2       0.75         1020      1350     2.0           0
# 21611         3       2.50         1600      2388     2.0           0
# 21612         2       0.75         1020      1076     2.0           0
#
#        sqft_above  sqft_basement  yr_built
# 0            1180              0      1955
# ...

# %%
dout= data[["price"]]

#print the output

dout
# Out:
#           price
# 0      221900.0
# 1      538000.0
# 2      180000.0
# 3      604000.0
# 4      510000.0
# ...         ...
# 21608  360000.0
# 21609  400000.0
# 21610  402101.0
# 21611  400000.0
# 21612  325000.0
#
# [21613 rows x 1 columns]

# %%
#data split from x and y
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test = train_test_split(dipt,dout,test_size=0.10,random_state=10)

# %%
len(x_train)
# Out:
# 19451

# %%
len(x_test)
# Out:
# 2162

# %%
len(y_train)
# Out:
# 19451

# %%
len(y_test)
# Out:
# 2162

# %%
#Logistic regression algorithm used already import the header file
lr =LogisticRegression()
lr.fit(x_train,y_train)
lr.predict(x_test)
lr.score(x_test,y_test)
# Out:
# C:\Users\shant\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\Users\shant\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# 0.00971322849213691

# %%
ld =DecisionTreeClassifier()
ld.fit(x_train,y_train)
ld.predict(x_test)
ld.score(x_test,y_test)
# Out:
# 0.004162812210915819

# %%
#save as module.pickle
with open ("module.pickle","wb") as f:
    pickle.dump(lr,f)
